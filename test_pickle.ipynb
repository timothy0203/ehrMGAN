# %%
import pickle
with open("data/real/mimic/vital_sign_24hrs_5_var_mimiciv.pkl", "rb") as f:
# with open("data/real/mimic/med_interv_24hrs_p4.pkl", "rb") as f:
    data = pickle.load(f)

# %%
data
# Out:
# array([[[0.49295775, 0.36666667, 0.93      , 0.36708861, 0.35      ],
#         [0.5399061 , 0.36666667, 0.92      , 0.36708861, 0.35      ],
#         [0.49765258, 0.33333333, 0.95      , 0.36708861, 0.35      ],
#         ...,
#         [0.44131455, 0.36666667, 1.        , 0.24050633, 0.35      ],
#         [0.45539906, 0.46666667, 1.        , 0.24050633, 0.35      ],
#         [0.45539906, 0.46666667, 1.        , 0.24050633, 0.35      ]],
#
#        [[0.37558685, 0.5111    , 1.        , 0.36708861, 0.375     ],
#         [0.37558685, 0.26666667, 1.        , 0.24050633, 0.375     ],
#         [0.37558685, 0.6       , 0.98      , 0.24050633, 0.375     ],
#         ...,
#         [0.30516432, 0.56666667, 1.        , 0.24050633, 0.375     ],
#         [0.30516432, 0.56666667, 1.        , 0.24050633, 0.375     ],
#         [0.30516432, 0.56666667, 1.        , 0.24050633, 0.375     ]],
#
#        [[0.37089202, 0.46666667, 1.        , 1.        , 0.3       ],
# ...

# %%
data.shape
# Out:
# (16062, 24, 5)

# %%
import pickle
import numpy as np

# Step 1: Load the .pkl file
# with open('data/real/mimic/vital_sign_24hrs_p4.pkl', 'rb') as f:
#     data = pickle.load(f)

# Step 2: Save the data to a .txt file
np.savetxt('data/real/mimic/vital_sign_24hrs_5_var_mimiciv.txt', data.reshape(-1, data.shape[-1]))

# Step 3: Read the data back from the .txt file
loaded_data = np.loadtxt('data/real/mimic/vital_sign_24hrs_5_var_mimiciv.txt')

# Step 4: Reshape the data to the original shape
loaded_data = loaded_data.reshape(data.shape[0], data.shape[1], data.shape[2])

# Verify the shape
print(loaded_data.shape)
# Out:
# (16062, 24, 5)

# %%
import pickle
import numpy as np
inter_filename = "med_interv_24hrs_5_var_mimiciv"
# Step 1: Load the .pkl file
with open(f'data/real/mimic/{inter_filename}.pkl', 'rb') as f:
    data = pickle.load(f)

# Step 2: Save the data to a .txt file
np.savetxt(f'data/real/mimic/{inter_filename}.txt', data.reshape(-1, data.shape[-1]))

# Step 3: Read the data back from the .txt file
loaded_data = np.loadtxt(f'data/real/mimic/{inter_filename}.txt')

# Step 4: Reshape the data to the original shape
loaded_data = loaded_data.reshape(data.shape[0], data.shape[1], data.shape[2])

# Verify the shape
print(loaded_data.shape)
# Out:
# (16062, 24, 1)

# %%
import pandas as pd
statics_label = pd.read_csv('data/real/mimic/static_data_5_var_mimiciv.csv')
# statics_label = pd.read_csv('data/real/mimic/static_data_mimiciv.csv')
statics_label
# Out:
#        subject_id   hadm_id   stay_id  index gender                    race  \
# 0        10001884  26184834  37510196      3      F  BLACK/AFRICAN AMERICAN
# 1        10002013  23581541  39060235      4      F                   OTHER
# 2        10002760  28094813  31831386     11      M        UNABLE TO OBTAIN
# 3        10004235  24181354  34100191     17      M      BLACK/CAPE VERDEAN
# 4        10004422  21255400  32155744     18      M                   WHITE
# ...           ...       ...       ...    ...    ...                     ...
# 16057    19998843  24842066  30988867  46093      M                 UNKNOWN
# 16058    19999068  21606769  30143796  46095      M                   WHITE
# 16059    19999442  26785317  32336619  46098      M                   WHITE
# 16060    19999840  21033226  38978960  46101      M                   WHITE
# 16061    19999987  23865745  36195440  46102      F                 UNKNOWN
#
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 2.3 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/11.6 MB 4.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.6 MB 6.3 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/11.6 MB 13.7 MB/s eta 0:00:01
#    ------------------- -------------------- 5.6/11.6 MB 27.4 MB/s eta 0:00:01
#    ------------------------- -------------- 7.5/11.6 MB 30.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.6 MB 27.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 50.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/507.9 kB ? eta -:--:--
#    --------------------------------------- 507.9/507.9 kB 16.1 MB/s eta 0:00:00
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# ...

# %%
# Step 1: Load the .pkl file
with open('data/real/mimic/statics.pkl', 'rb') as f:
    data = pickle.load(f)
data.shape
# Out:
# C:\Users\hmilab\AppData\Local\Temp\ipykernel_19196\4003807607.py:3: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f)
# (28344, 28)

# %%
import pickle
import numpy as np
import pandas as pd

# Step 1: Load the .pkl file
with open('data/real/mimic/statics.pkl', 'rb') as f:
    data = pickle.load(f)

# Convert DataFrame to NumPy array, ensuring all data is numeric
data_array = data.apply(pd.to_numeric, errors='coerce').values

# Step 2: Save the data to a .txt file
np.savetxt('data/real/mimic/statics.txt', data_array, fmt='%.18e')

# Step 3: Read the data back from the .txt file
loaded_data = np.loadtxt('data/real/mimic/statics.txt')

# Step 4: Reshape the data to the original shape
loaded_data = loaded_data.reshape(28344, 28)

# Verify the shape
print(loaded_data.shape)
# Out:
# C:\Users\hmilab\AppData\Local\Temp\ipykernel_19196\3406573066.py:7: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f)
# (28344, 28)

# %%
loaded_data
# Out:
# array([[         nan,          nan,  76.52679248, ...,   1.        ,
#           0.        , 145.        ],
#        [         nan,          nan,  47.84504657, ...,   1.        ,
#           0.        ,  40.        ],
#        [         nan,          nan,  65.94229705, ...,   1.        ,
#           0.        ,  88.        ],
#        ...,
#        [         nan,          nan,  65.77215453, ...,   1.        ,
#           0.        ,  47.        ],
#        [         nan,          nan,  88.69894246, ...,   1.        ,
#           0.        ,  51.        ],
#        [         nan,          nan,  63.98359132, ...,   1.        ,
#           0.        ,  26.        ]])

# %%
with open('data/real/mimic/statics.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
# C:\Users\hmilab\AppData\Local\Temp\ipykernel_19196\2690489544.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f)
#                               gender              ethnicity        age  \
# subject_id hadm_id icustay_id
# 3          145834  211552          M                  WHITE  76.526792
# 4          185777  294638          F                  WHITE  47.845047
# 6          107064  228232          F                  WHITE  65.942297
# ...

# %%
import pickle
import pandas as pd

# Step 1: Load the .pkl file
with open('data/real/mimic/statics.pkl', 'rb') as f:
    data = pickle.load(f)

# Step 2: Save the DataFrame to a CSV file
data.to_csv('data/real/mimic/statics.csv', index=False)

# Verify the saved file
print("DataFrame saved to 'data/real/mimic/statics.csv'")
# Out:
# C:\Users\hmilab\AppData\Local\Temp\ipykernel_19196\582708276.py:6: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f)
# DataFrame saved to 'data/real/mimic/statics.csv'

# %%
import numpy as np
gen_data = np.load("D:/Timothy_Chang/ehrMGAN/data/fake/epoch6/gen_data.npz")
gen_data
# Out:
# NpzFile 'D:/Timothy_Chang/ehrMGAN/data/fake/epoch6/gen_data.npz' with keys: c_gen_data, d_gen_data

# %%
gen_data["c_gen_data"].shape
# Out:
# (28160, 24, 104)

# %%
gen_data["d_gen_data"].shape
# Out:
# (28160, 24, 14)

# %%
patinet_num = 16062
# patinet_num = 36553
filename_postfix = '5_var'
continuous_x = np.loadtxt(f'data/real/mimic/vital_sign_24hrs_{filename_postfix}_mimiciv.txt')
continuous_x = continuous_x.reshape(patinet_num, 24, 5)

# with open(os.path.join('data/real/', args.dataset, 'med_interv_24hrs_p4.pkl'), 'rb') as f:
#     discrete_x = pickle.load(f)
discrete_x = np.loadtxt(f'data/real/mimic/med_interv_24hrs_{filename_postfix}_mimiciv.txt')
discrete_x = discrete_x.reshape(patinet_num, 24, 1)

# with open(os.path.join('data/real/', args.dataset, 'statics.pkl'), 'rb') as f:
#     statics_label = pickle.load(f)
statics_label = pd.read_csv(f'data/real/mimic/static_data_{filename_postfix}_mimiciv.csv')
statics_label = np.asarray(statics_label)[:, 0].reshape([-1, 1])

# %%
continuous_x.shape
# Out:
# (16062, 24, 5)

# %%
import numpy as np
import pandas as pd

# Original number of patients
patient_num = 16062

# Number of patients to subset
subset_patient_num = 1000  # Change this value to the desired subset size

filename_postfix = '5_var'

# Load and reshape continuous data
continuous_x = np.loadtxt(f'data/real/mimic/vital_sign_24hrs_{filename_postfix}_mimiciv.txt')
continuous_x = continuous_x.reshape(patient_num, 24, 5)
continuous_x_subset = continuous_x[:subset_patient_num]

# Load and reshape discrete data
discrete_x = np.loadtxt(f'data/real/mimic/med_interv_24hrs_{filename_postfix}_mimiciv.txt')
discrete_x = discrete_x.reshape(patient_num, 24, 1)
discrete_x_subset = discrete_x[:subset_patient_num]

# Load and reshape static labels
statics_label = pd.read_csv(f'data/real/mimic/static_data_{filename_postfix}_mimiciv.csv')
statics_label = np.asarray(statics_label)[:, 0].reshape([-1, 1])
statics_label_subset = statics_label[:subset_patient_num]

# Now continuous_x_subset, discrete_x_subset, and statics_label_subset contain the subset of the data

# %%
continuous_x_subset = continuous_x[:subset_patient_num]
continuous_x_subset.shape
# Out:
# (1000, 24, 5)
